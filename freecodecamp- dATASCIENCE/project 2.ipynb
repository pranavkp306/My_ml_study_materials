# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('adult.data.csv')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.notna().sum()
# Out:
# age               32561
# workclass         32561
# fnlwgt            32561
# education         32561
# education-num     32561
# marital-status    32561
# occupation        32561
# relationship      32561
# race              32561
# sex               32561
# capital-gain      32561
# capital-loss      32561
# hours-per-week    32561
# native-country    32561
# salary            32561
# dtype: int64

# %%
df['race'].value_countss()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df['age'],df['sex']
# Out:
# (0        39
#  1        50
#  2        38
#  3        53
#  4        28
#           ..
#  32556    27
#  32557    40
#  32558    58
#  32559    22
#  32560    52
#  Name: age, Length: 32561, dtype: int64,
#  0          Male
#  1          Male
#  2          Male
#  3          Male
#  4        Female
#            ...
#  32556    Female
#  32557      Male
#  32558    Female
#  32559      Male
#  32560    Female
#  Name: sex, Length: 32561, dtype: object)

# %%
df[['age','sex']]
# Out:
#        age     sex
# 0       39    Male
# 1       50    Male
# 2       38    Male
# 3       53    Male
# 4       28  Female
# ...    ...     ...
# 32556   27  Female
# 32557   40    Male
# 32558   58  Female
# 32559   22    Male
# 32560   52  Female
#
# [32561 rows x 2 columns]

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
males=(df.loc[df['sex']=='Male'])['age'].mean()
males
# Out:
# 39.43354749885268

# %%
(df.loc[df['sex']=='Male'])['age'].mean()
# Out:
# 39.43354749885268

# %%
males['age'].mean()
# Out:
# 39.43354749885268

# %%
males.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  21790.000000  2.179000e+04   21790.000000  21790.000000  21790.000000
# mean      39.433547  1.917714e+05      10.102891   1329.370078    100.213309
# std       13.370630  1.067407e+05       2.662630   8326.312095    429.763097
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       29.000000  1.182008e+05       9.000000      0.000000      0.000000
# 50%       38.000000  1.801400e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.411462e+05      13.000000      0.000000      0.000000
# max       90.000000  1.455435e+06      16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count    21790.000000
# mean        42.428086
# std         12.119755
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         49.000000
# max         99.000000

# %%
df[['education','education-num']]
# Out:
#         education  education-num
# 0       Bachelors             13
# 1       Bachelors             13
# 2         HS-grad              9
# 3            11th              7
# 4       Bachelors             13
# ...           ...            ...
# 32556  Assoc-acdm             12
# 32557     HS-grad              9
# 32558     HS-grad              9
# 32559     HS-grad              9
# 32560     HS-grad              9
#
# [32561 rows x 2 columns]

# %%
df['education-num'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education-num, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
total=df['education-num'].count()
total
# Out:
# 32561

# %%
btech=(df.loc[df['education-num']==13].count()['education-num'])/(df['education-num'].count())*100
btech
# Out:
# 16.44605509658794

# %%
percentile=(btech/total)*100
percentile
# Out:
# 16.44605509658794

# %%
temp=df.loc[(df['education-num']==13) | (df['education-num']==16) | (df['education-num']==14)]
temp
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
(df.count()-temp.count())['age']
# Out:
# 25070

# %%
temp['education'].value_counts()
# Out:
# Bachelors    5355
# Masters      1723
# Doctorate     413
# Name: education, dtype: int64

# %%
with_advance=round((temp['salary']== '>50K').sum()/(temp['education'].count())*100,1)
with_advance
# Out:
# 46.5

# %%
length=temp['education'].count()
length
# Out:
# 7491

# %%
percentage=(with_advance/length)*100
percentage
# Out:
# 46.535843011613935

# %%
temp=df.loc[~((df['education-num']==13) | (df['education-num']==16) | (df['education-num']==14))]
temp
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
temp['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
temp['salary'].value_counts()
# Out:
# <=50K    20715
# >50K      4355
# Name: salary, dtype: int64

# %%
round((temp['salary']== '>50K').sum()/(temp['salary']).count()*100,1)
# Out:
# 17.4

# %%
without_advance=(temp['salary']== '>50K').sum()
without_advance
# Out:
# 4355

# %%
length=(temp['salary']).count()
length
# Out:
# 25070

# %%
percentage=(without_advance/length)*100
percentage
# Out:
# 17.3713601914639

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
min_hrs=df.loc[(df['salary']== '>50K') & (df['hours-per-week']<=1)].count()['age']
min_hrs
# Out:
# 2

# %%
leng=df.loc[df['hours-per-week']==1].count()["age"]
leng
# Out:
# 20

# %%
round((min_hrs/leng)*100,1)
# Out:
# 10.0

# %%
df.groupby(['native-country']).count()
# Out:
#                               age  workclass  fnlwgt  education  \
# native-country
# ?                             583        583     583        583
# Cambodia                       19         19      19         19
# Canada                        121        121     121        121
# China                          75         75      75         75
# Columbia                       59         59      59         59
# Cuba                           95         95      95         95
# Dominican-Republic             70         70      70         70
# Ecuador                        28         28      28         28
# El-Salvador                   106        106     106        106
# England                        90         90      90         90
# France                         29         29      29         29
# Germany                       137        137     137        137
# Greece                         29         29      29         29
# ...

# %%
length
# Out:
# 32561

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df2=df.loc[df['salary']=='>50K']
df2
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
df2.groupby("native-country").count()
# Out:
#                      age  workclass  fnlwgt  education  education-num  \
# native-country
# ?                    146        146     146        146            146
# Cambodia               7          7       7          7              7
# Canada                39         39      39         39             39
# China                 20         20      20         20             20
# Columbia               2          2       2          2              2
# Cuba                  25         25      25         25             25
# Dominican-Republic     2          2       2          2              2
# Ecuador                4          4       4          4              4
# El-Salvador            9          9       9          9              9
# England               30         30      30         30             30
# France                12         12      12         12             12
# Germany               44         44      44         44             44
# ...

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df2=df.copy()

# %%
(df2.loc[df2['native-country']=="?" , 'native-country'])=np.nan

# %%
df2['native-country'].isnull().value_counts()
# Out:
# False    31978
# True       583
# Name: native-country, dtype: int64

# %%
df2['native-country'].fillna(method ='ffill', inplace = True)

# %%
df2['native-country'].value_counts()
# Out:
# United-States                 29694
# Mexico                          657
# Philippines                     200
# Germany                         141
# Canada                          124
# Puerto-Rico                     118
# El-Salvador                     109
# India                           101
# Cuba                             97
# England                          93
# Jamaica                          83
# South                            80
# China                            77
# Dominican-Republic               74
# Italy                            73
# Vietnam                          72
# Guatemala                        66
# Japan                            63
# Columbia                         61
# Poland                           60
# Taiwan                           51
# Haiti                            45
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
(df2.loc[df2['salary']=='>50K'])
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
rich_by_country=df[df['salary'] == '>50K'].groupby('native-country')['native-country'].count()
(rich_by_country / df.groupby('native-country')['native-country'].count()).idxmax()
round((rich_by_country / df.groupby('native-country')['native-country'].count()).max()*100,1)
# Out:
# 41.9

# %%
final=(df['native-country'] == 'India') & (df['salary'] == '>50K')

# %%
df[final].groupby('occupation').count()['age'].idxmax()
# Out:
# 'Prof-specialty'

# %%
ind['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Transport-moving     1
# Sales                1
# Name: occupation, dtype: int64

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df['native-country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...
